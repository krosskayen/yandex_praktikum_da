# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-общей-информации-по-предоставленным-данным" data-toc-modified-id="Изучение-общей-информации-по-предоставленным-данным-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение общей информации по предоставленным данным</a></span></li><li><span><a href="#Подготовка-данных-к-исследованию" data-toc-modified-id="Подготовка-данных-к-исследованию-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка данных к исследованию</a></span><ul class="toc-item"><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Добавление-столбцов-с-данными" data-toc-modified-id="Добавление-столбцов-с-данными-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Добавление столбцов с данными</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Распределение-количества-выпускаемых-игр-по-годам-выпуска" data-toc-modified-id="Распределение-количества-выпускаемых-игр-по-годам-выпуска-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Распределение количества выпускаемых игр по годам выпуска</a></span></li><li><span><a href="#Распределение-количества-проданных-копий-игр-по-актуальных-платформ" data-toc-modified-id="Распределение-количества-проданных-копий-игр-по-актуальных-платформ-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Распределение количества проданных копий игр по актуальных платформ</a></span></li><li><span><a href="#Динамика-продаж-игр-для-актуальных-платформ-в-2012-2016-гг." data-toc-modified-id="Динамика-продаж-игр-для-актуальных-платформ-в-2012-2016-гг.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Динамика продаж игр для актуальных платформ в 2012-2016 гг.</a></span></li><li><span><a href="#Распределение-игр-по-количеству-продаж-для-актуальных-платформ" data-toc-modified-id="Распределение-игр-по-количеству-продаж-для-актуальных-платформ-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Распределение игр по количеству продаж для актуальных платформ</a></span></li><li><span><a href="#Зависимость-между-отзывами-критиков/пользователей-и-продажами-для-актуальных-платформ" data-toc-modified-id="Зависимость-между-отзывами-критиков/пользователей-и-продажами-для-актуальных-платформ-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Зависимость между отзывами критиков/пользователей и продажами для актуальных платформ</a></span></li><li><span><a href="#Распределение-игр-по-жанрам" data-toc-modified-id="Распределение-игр-по-жанрам-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Распределение игр по жанрам</a></span></li></ul></li><li><span><a href="#Портрет-пользователя-каждого-региона-(NA,-EU,-JP)" data-toc-modified-id="Портрет-пользователя-каждого-региона-(NA,-EU,-JP)-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Портрет пользователя каждого региона (NA, EU, JP)</a></span><ul class="toc-item"><li><span><a href="#Наиболее-популярные-игровые-платформы-(топ-5)--в-каждом-из-регионов" data-toc-modified-id="Наиболее-популярные-игровые-платформы-(топ-5)--в-каждом-из-регионов-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Наиболее популярные игровые платформы (топ-5)  в каждом из регионов</a></span></li><li><span><a href="#Наиболее-популярные-жанры-игр-(топ-5)-в-каждом-из-регионов" data-toc-modified-id="Наиболее-популярные-жанры-игр-(топ-5)-в-каждом-из-регионов-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Наиболее популярные жанры игр (топ-5) в каждом из регионов</a></span></li><li><span><a href="#Влияние-рейтинга-ESRB-на-продажи-в-регионах" data-toc-modified-id="Влияние-рейтинга-ESRB-на-продажи-в-регионах-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Влияние рейтинга ESRB на продажи в регионах</a></span></li></ul></li><li><span><a href="#Проверка-гипотез-и-пояснения" data-toc-modified-id="Проверка-гипотез-и-пояснения-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Проверка гипотез и пояснения</a></span><ul class="toc-item"><li><span><a href="#Проверка-гипотезы-о-равенстве-пользовательских-рейтингов-платформ-Xbox-One-и-PC" data-toc-modified-id="Проверка-гипотезы-о-равенстве-пользовательских-рейтингов-платформ-Xbox-One-и-PC-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Проверка гипотезы о равенстве пользовательских рейтингов платформ Xbox One и PC</a></span></li><li><span><a href="#Проверка-гипотезы-о-равенстве-пользовательских-рейтингов-жанров-Action-и-Sports" data-toc-modified-id="Проверка-гипотезы-о-равенстве-пользовательских-рейтингов-жанров-Action-и-Sports-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Проверка гипотезы о равенстве пользовательских рейтингов жанров Action и Sports</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Определение успешности продаж компьютерных игр
#
# Вам предоставлен файл из открытых источников с историческими данными о продажах компьютерных игр за период до 2016 года. Необходимо проанализировать предоставленные данные и выявить закономерности, определяющие успешность игры. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламную компанию на 2017 год.

# %% [markdown]
# ## Изучение общей информации по предоставленным данным

# %%
# импортирование необходимых библиотек
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams
sns.set_style("whitegrid")
# %config InlineBackend.figure_format='retina'
# %matplotlib inline

from scipy import stats as st
from tqdm import tqdm

import warnings
warnings.filterwarnings(action='ignore')

# укажем автоматическое округление формата float до 3 цифр после запятой
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# укажем стандартные размеры графиков в дюймах
rcParams['figure.figsize'] = 15, 7.5

# снимем ограничение на количество отображаемых столбцов
pd.set_option('display.max_columns', None)

# %% [markdown]
# Прочитаем исходные файлы с данными и сохраним их в переменную, затем ознакомимся.

# %%
df = pd.read_csv('games.csv')

# %%
display(df.info())
display(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB
# None
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii         2006.000        Sports    41.360
# ...

# %% [markdown]
# Предоставленная таблица `games` состоит из 16715 строк и 11 столбцов с данными о продаже игр. К каждому из столбцов имеется описание содержащихся в них данных:
# * `Name` — название игры;
# * `Platform` — платформа;
# * `Year_of_Release` — год выпуска;
# * `Genre` — жанр игры;
# * `NA_sales` — продажи в Северной Америке (миллионы проданных копий);
# * `EU_sales` — продажи в Европе (миллионы проданных копий);
# * `JP_sales` — продажи в Японии (миллионы проданных копий);
# * `Other_sales` — продажи в других странах (миллионы проданных копий);
# * `Critic_Score` — оценка критиков (максимум 100);
# * `User_Score` — оценка пользователей (максимум 10);
# * `Rating` — возрастной рейтинг от организации ESRB (англ. Entertainment Software Rating Board).
#
# Столбцы имеют в целом корректное наименование. В процессе подготовки данных стоит привести их к нижнему регистру, а типы данных привести к корректным.
# В нескольких столбцах имеются пропущенные значения, однако исходя из предоставленного описания к предоставленной таблице, данные за 2016 год могут быть неполными, необходимо подробнее с ними ознакомиться.

# %% [markdown]
# ## Подготовка данных к исследованию

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# Для начала изменим наименование столбцов, в верхнем регистре на нижний.
#
# Предварительно мы установили, что в нескольких столбцах имеется большое количество пропусков, посмотрим какую часть они занимают относительно всей выборки, а также посмотрим что можно сделать для их устранения.
# После чего приведем данные в столбцах к корректному типу для проведения дальнейших преобразований и корректности дальнейшего исследования.

# %%
df.columns = df.columns.str.lower()

# %%
df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii         2006.000        Sports    41.360
# 1         Super Mario Bros.      NES         1985.000      Platform    29.080
# 2            Mario Kart Wii      Wii         2008.000        Racing    15.680
# 3         Wii Sports Resort      Wii         2009.000        Sports    15.610
# 4  Pokemon Red/Pokemon Blue       GB         1996.000  Role-Playing    11.270
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0    28.960     3.770        8.450        76.000          8      E
# 1     3.580     6.810        0.770           NaN        NaN    NaN
# 2    12.760     3.790        3.290        82.000        8.3      E
# 3    10.930     3.280        2.950        80.000          8      E
# 4     8.890    10.220        1.000           NaN        NaN    NaN

# %%
# подсчёт пропусков
df.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %% [markdown]
# Выясним процентное соотношение пропусков в столбцах к общему числу значений в столбце.

# %%
df.isna().mean().sort_values()
# Out:
# platform          0.000
# na_sales          0.000
# eu_sales          0.000
# jp_sales          0.000
# other_sales       0.000
# name              0.000
# genre             0.000
# year_of_release   0.016
# user_score        0.401
# rating            0.405
# critic_score      0.513
# dtype: float64

# %% [markdown]
# Посмотрим на столбец с названием игры и жанра, в которых имеются пропущенные значения.

# %%
df.loc[df['name'].isna() | df['genre'].isna()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN         1993.000   NaN     1.780     0.530     0.000
# 14244  NaN      GEN         1993.000   NaN     0.000     0.000     0.030
#
#        other_sales  critic_score user_score rating
# 659          0.080           NaN        NaN    NaN
# 14244        0.000           NaN        NaN    NaN

# %% [markdown]
# Заполнить данные в столбцах какими-либо значениями не представляется возможным. Поскольку данные датированы 1993 годом и в них не указан какой-либо жанр, они бесполезны для нашего исследования, их можно удалить.

# %%
df = df.dropna(subset=['name'], axis=0).reset_index(drop=True)
print(df[['name','genre']].isna().sum())
# Out:
# name     0
# genre    0
# dtype: int64

# %% [markdown]
# Посмотрим на значения каждого столбца подробнее.

# %%
df.year_of_release.value_counts()
# Out:
# 2008.000    1427
# 2009.000    1426
# 2010.000    1255
# 2007.000    1197
# 2011.000    1136
# 2006.000    1006
# 2005.000     939
# 2002.000     829
# 2003.000     775
# 2004.000     762
# 2012.000     653
# 2015.000     606
# 2014.000     581
# 2013.000     544
# 2016.000     502
# 2001.000     482
# 1998.000     379
# 2000.000     350
# 1999.000     338
# 1997.000     289
# 1996.000     263
# 1995.000     219
# 1994.000     121
# 1993.000      60
# 1981.000      46
# 1992.000      43
# 1991.000      41
# 1982.000      36
# 1986.000      21
# 1989.000      17
# 1983.000      17
# 1990.000      16
# 1987.000      16
# 1988.000      15
# 1985.000      14
# 1984.000      14
# 1980.000       9
# Name: year_of_release, dtype: int64

# %%
df.genre.value_counts()
# Out:
# Action          3369
# Sports          2348
# Misc            1750
# Role-Playing    1498
# Shooter         1323
# Adventure       1303
# Racing          1249
# Platform         888
# Simulation       873
# Fighting         849
# Strategy         683
# Puzzle           580
# Name: genre, dtype: int64

# %%
df.loc[df.year_of_release.isna()]
# Out:
#                                     name platform  year_of_release  \
# 183                      Madden NFL 2004      PS2              NaN
# 377                     FIFA Soccer 2004      PS2              NaN
# 456           LEGO Batman: The Videogame      Wii              NaN
# 475           wwe Smackdown vs. Raw 2006      PS2              NaN
# 609                       Space Invaders     2600              NaN
# ...                                  ...      ...              ...
# 16371  PDC World Championship Darts 2008      PSP              NaN
# 16403                      Freaky Flyers       GC              NaN
# 16446                          Inversion       PC              NaN
# 16456        Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16520                       Virtua Quest       GC              NaN
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 183          Sports     4.260     0.260     0.010        0.710        94.000
# ...

# %% [markdown]
# Значения в столбце с наименованием жанра вполне корректны, какие-либо исправления не требуются.
#
# Пропущенные значения в столбце с годом релиза вероятнее всего появились вследствие некорректного заполнения данных в базе (так например, некоторые названия уже содержат год релиза). Теоретически можно было бы заполнить данные в столбце корректными значениями, но это займет неоправданно большое количество времени.
#
# Строки с данными, в которых имеются пропущенные значения в столбце с годом релиза составляют небольшое количество (1.6%), а поскольку нам ставится задача прогнозирования продаж на конкретный год (2017), в связи с этим указанные данные бесполезны для нашего исследования, удалим их.

# %%
df = df.dropna(subset=['year_of_release'], axis=0).reset_index(drop=True)
print(df[['year_of_release']].isna().sum())
# Out:
# year_of_release    0
# dtype: int64

# %%
df.critic_score.value_counts()
# Out:
# 70.000    252
# 71.000    248
# 75.000    240
# 80.000    235
# 73.000    234
#          ...
# 20.000      3
# 29.000      3
# 21.000      1
# 17.000      1
# 13.000      1
# Name: critic_score, Length: 81, dtype: int64

# %% [markdown]
# Данные вполне корректны, исходя из имеющихся значений в столбце, тип данных в столбце с оценками критиков можно заменить на int.

# %%
df.user_score.value_counts()
# Out:
# tbd    2376
# 7.8     322
# 8       285
# 8.2     276
# 8.3     252
#        ...
# 1.1       2
# 1.9       2
# 9.6       2
# 0         1
# 9.7       1
# Name: user_score, Length: 96, dtype: int64

# %% [markdown]
# Большое количество игр (2424) имеет рейтинг пользователей 'tbd', что расшифровывается как 'To Be Determined'. Буквально это означает, 'будет определено', т.е. пользователи еще не ставили оценки этой игре. Для приведения типа данных в столбце к корректному типу, необходимо будет избавиться от этого значения, заменив его на NaN. Это не помешает нам в исследовании, т.к. соответствующий тип корректно обрабатывается при проведении с ним математических операций. После чего, изменим тип данных в столбце с object на float.

# %%
df.loc[(df['user_score'] == 'tbd'), 'user_score'] = np.nan

# %%
df.user_score.value_counts()
# Out:
# 7.8    322
# 8      285
# 8.2    276
# 8.3    252
# 7.5    249
#       ...
# 1.5      2
# 0.3      2
# 1.1      2
# 0        1
# 9.7      1
# Name: user_score, Length: 95, dtype: int64

# %%
df.rating.value_counts()
# Out:
# E       3921
# T       2905
# M       1536
# E10+    1393
# EC         8
# K-A        3
# AO         1
# RP         1
# Name: rating, dtype: int64

# %% [markdown]
# Большое количество незаполненных значений в столбцах с оценкой пользователей и оценкой критиков предположительно объясняется тем, что далеко не всем играм (особенно имеющим незначительное число продаж), пользователи/критики оставляют какую-либо оценку, либо эта оценка берется из каких-то единственных источников (а не большого количества тематических сайтов/форумов/журналов с рейтингами по всем странам).
#
# Что касается пропусков в столбце с данными о рейтинге, то согласно данным из открытых источников Entertainment Software Rating Board (ESRB) - негосударственная организация, основное направление деятельности которой состоит в принятии и определении рейтингов для компьютерных видеоигр и другого развлекательного программного обеспечения в США и Канаде, т.е. если игра не поставлялась на рынки этих двух стран, рейтинг ей мог и не присваиваться.

# %% [markdown]
# Проведем необходимые преобразования типов данных и удостоверимся в отсутствии ошибок.

# %%
df['user_score'] = pd.to_numeric(df['user_score'], errors='coerce')

# %%
try:
    df['year_of_release'] = df['year_of_release'].astype('int')
except:
    print('Error_change_type')
display(df.dtypes)
# Out:
# name                object
# platform            object
# year_of_release      int32
# genre               object
# na_sales           float64
# eu_sales           float64
# jp_sales           float64
# other_sales        float64
# critic_score       float64
# user_score         float64
# rating              object
# dtype: object

# %% [markdown]
# Посмотрим на числовые данные в столбцах и убедимся в отсутствии аномальных значений.

# %%
df.describe(percentiles=[.25, .75, .95])
# Out:
#        year_of_release  na_sales  eu_sales  jp_sales  other_sales  \
# count        16444.000 16444.000 16444.000 16444.000    16444.000
# mean          2006.486     0.264     0.146     0.078        0.048
# std              5.876     0.818     0.507     0.311        0.188
# min           1980.000     0.000     0.000     0.000        0.000
# 25%           2003.000     0.000     0.000     0.000        0.000
# 50%           2007.000     0.080     0.020     0.000        0.010
# 75%           2010.000     0.240     0.110     0.040        0.030
# 95%           2015.000     1.060     0.630     0.360        0.200
# max           2016.000    41.360    28.960    10.220       10.570
#
#        critic_score  user_score
# count      7983.000    7463.000
# mean         68.994       7.126
# std          13.920       1.499
# min          13.000       0.000
# 25%          60.000       6.400
# 50%          71.000       7.500
# 75%          79.000       8.200
# 95%          89.000       8.900
# ...

# %% [markdown]
# Какие-либо аномалии в сводных статистиках на данном этапе не выявлены.

# %% [markdown]
# ### Добавление столбцов с данными

# %% [markdown]
# Добавим в таблицу с исследуемыми данными столбец с суммарными продажами во всех регионах, а затем убедимся в корректности проведенных преобразований.

# %%
df['total_sales'] = (df.loc[:, 'na_sales':'other_sales']).sum(axis=1)

# %%
df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports    41.360
# 1         Super Mario Bros.      NES             1985      Platform    29.080
# 2            Mario Kart Wii      Wii             2008        Racing    15.680
# 3         Wii Sports Resort      Wii             2009        Sports    15.610
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing    11.270
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0    28.960     3.770        8.450        76.000       8.000      E
# 1     3.580     6.810        0.770           NaN         NaN    NaN
# 2    12.760     3.790        3.290        82.000       8.300      E
# 3    10.930     3.280        2.950        80.000       8.000      E
# 4     8.890    10.220        1.000           NaN         NaN    NaN
#
#    total_sales
# 0       82.540
# 1       40.240
# 2       35.520
# 3       32.770
# ...

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Распределение количества выпускаемых игр по годам выпуска

# %% [markdown]
# Создадим таблицу с данными по году выпуска и количеству игр, выпущенных в указаный период, затем построим по ней диаграмму.

# %%
games_for_years = df.pivot_table(index='year_of_release', values='name', aggfunc='count').reset_index()
games_for_years.columns = ['year', 'count_games']
display(games_for_years.head())
# Out:
#    year  count_games
# 0  1980            9
# 1  1981           46
# 2  1982           36
# 3  1983           17
# 4  1984           14

# %%
(sns.barplot(x='year', y='count_games', palette='deep', 
    data=games_for_years) 
    .set(title='Общее количество выпущенных игр по годам', 
    xlabel='Год выпуска', 
    ylabel='Количество игр (в штуках)'))
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Количество выпускаемых игр планомерно увеличивалось примерно с начала-середины 90-х годов ХХ века и достигло своего пика в 2008-2009 годах. После чего, примерно с 2012 года заметен довольно резкий спад в количестве выпускаемых игр, с 2012 по 2016 годы продажи игр держатся примерно на одном уровне.
#
# Для дальнейшего исследования пригодятся данные по продажам за период с 2012 по 2016 год. Данные за более ранние периоды могут значительно исказить наше исследование, поскольку с 2007 по 2011 годы выпускали значительно больше игр, чем в последующие годы, а одних лишь данных за 2015-2016 годы может быть недостаточно для исследования.

# %% [markdown]
# ### Распределение количества проданных копий игр по актуальных платформ

# %% [markdown]
# Создадим таблицу для платформ с наибольшими суммарными продажами по каждой из платформ, а затем построим диаграмму и посмотрим на распределение продаж для платформ.

# %%
platforms = (df.pivot_table(index='platform', values='total_sales', aggfunc='sum')
            .sort_values(by='total_sales', ascending=False).reset_index())
display(platforms.head(10))
# Out:
#   platform  total_sales
# 0      PS2     1233.560
# 1     X360      961.240
# 2      PS3      931.340
# 3      Wii      891.180
# 4       DS      802.780
# 5       PS      727.580
# 6      PS4      314.140
# 7      GBA      312.880
# 8      PSP      289.530
# 9      3DS      257.810

# %%
(sns.barplot(x='platform', y='total_sales', palette='deep', 
    data=platforms.sort_values(by='total_sales')) 
    .set(ylim=(0,1400), title='Общее количество проданных копий игр для каждой платформы', 
    xlabel='Платформа', 
    ylabel='Количество проданнных игр (в млн. штук)'))
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Из всех платформ по общему количеству проданных копий игр заметно выделяются PS2, X360, PS3, Wii, DS, PS. Построим распределение продаж по годам для каждой из этих платформ.

# %%
best_platforms_all_years = list(platforms.loc[:5, 'platform'])
display(best_platforms_all_years)
# Out:
# ['PS2', 'X360', 'PS3', 'Wii', 'DS', 'PS']

# %%
platforms_per_year = (df[df.platform.isin(best_platforms_all_years)].pivot_table(index=['platform', 'year_of_release'], 
                    values='total_sales', aggfunc='sum').reset_index())
display(platforms_per_year.head())
# Out:
#   platform  year_of_release  total_sales
# 0       DS             1985        0.020
# 1       DS             2004       17.270
# 2       DS             2005      130.140
# 3       DS             2006      119.810
# 4       DS             2007      146.940

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
fig.suptitle('Количество проданных игр на платформах по годам')

sns.barplot(ax=axes[0], x='year_of_release', y='total_sales', 
palette='deep', data=platforms_per_year.query('platform == "PS2"'))
axes[0].set(title='PS2', xlabel='Год выпуска', ylabel='Количество продаж (в млн. штук)')

sns.barplot(ax=axes[1], x='year_of_release', y='total_sales', 
palette='deep', data=platforms_per_year.query('platform == "X360"'))
axes[1].set(title='X360', xlabel='Год выпуска', ylabel='Количество продаж (в млн. штук)')
# Out:
# [Text(0.5, 1.0, 'X360'),
#  Text(0.5, 0, 'Год выпуска'),
#  Text(0, 0.5, 'Количество продаж (в млн. штук)')]

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
fig.suptitle('Количество проданных игр на платформах по годам')

sns.barplot(ax=axes[0], x='year_of_release', y='total_sales', 
palette='deep', data=platforms_per_year.query('platform == "PS3"'))
axes[0].set(title='PS3', xlabel='Год выпуска', ylabel='Количество проданных копий (в млн. штук)')

sns.barplot(ax=axes[1], x='year_of_release', y='total_sales', 
palette='deep', data=platforms_per_year.query('platform == "Wii"'))
axes[1].set(title='Wii', xlabel='Год выпуска', ylabel='Количество проданных копий (в млн. штук)')
# Out:
# [Text(0.5, 1.0, 'Wii'),
#  Text(0.5, 0, 'Год выпуска'),
#  Text(0, 0.5, 'Количество проданных копий (в млн. штук)')]

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
fig.suptitle('Количество проданных игр на платформах по годам')

sns.barplot(ax=axes[0], x='year_of_release', y='total_sales', 
palette='deep', data=platforms_per_year.query('platform == "DS"'))
axes[0].set(title='DS', xlabel='Год выпуска', ylabel='Количество продаж (в млн. штук)')

sns.barplot(ax=axes[1], x='year_of_release', y='total_sales', 
palette='deep', data=platforms_per_year.query('platform == "PS"'))
axes[1].set(title='PS', xlabel='Год выпуска', ylabel='Количество продаж (в млн. штук)')
# Out:
# [Text(0.5, 1.0, 'PS'),
#  Text(0.5, 0, 'Год выпуска'),
#  Text(0, 0.5, 'Количество продаж (в млн. штук)')]

# %% [markdown]
# Продажи игр в момент появления новой платформы, как правило относительно небольшие. На второй год продажи заметно увеличиваются и, как правило, в промежутке с 2 до 4-5 лет продажи держатся на стабильно высоком уровне, потом идут на спад. Платформы в целом дают продажи в промежутке от 7 до 9 лет, затем количество продаваемых игр на них становится крайне низким. Из общей картины выделяется только Wii, с первого года появления которой продажи игр сразу стали довольно высокими (по сравнению с другими платформами).
#
# Новые платформы появляются в промежутке от 5 до 6 лет, при этом не всегда продажи игр после появления новой платформы от того же производителя резко снижаются, например это заметно на графиках для платформ PS и PS2 в 2000-2001 гг. и для платформ PS2 и PS3 в 2006-2007 гг.

# %% [markdown]
# ### Динамика продаж игр для актуальных платформ в 2012-2016 гг.

# %% [markdown]
# Выделим платформы, которые были актуальны в исследуемом периоде и построим по ним диаграмму распределения по количеству проданных копий игр.

# %%
platforms_actual = df.query('year_of_release > 2011')
platforms_actual.head()
# Out:
#                           name platform  year_of_release         genre  \
# 16          Grand Theft Auto V      PS3             2013        Action
# 23          Grand Theft Auto V     X360             2013        Action
# 31   Call of Duty: Black Ops 3      PS4             2015       Shooter
# 33         Pokemon X/Pokemon Y      3DS             2013  Role-Playing
# 34  Call of Duty: Black Ops II      PS3             2012       Shooter
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 16     7.020     9.090     0.980        3.960        97.000       8.200
# 23     9.660     5.140     0.060        1.410        97.000       8.100
# 31     6.030     5.860     0.360        2.380           NaN         NaN
# 33     5.280     4.190     4.350        0.780           NaN         NaN
# 34     4.990     5.730     0.650        2.420        83.000       5.300
#
#    rating  total_sales
# 16      M       21.050
# 23      M       16.270
# 31    NaN       14.630
# ...

# %%
platforms_actual_sales = (platforms_actual.pivot_table(index='platform', 
                        values='total_sales', aggfunc='sum')
                        .sort_values(by='total_sales', ascending=False).reset_index())
display(platforms_actual_sales)
# Out:
#    platform  total_sales
# 0       PS4      314.140
# 1       PS3      288.790
# 2      X360      236.540
# 3       3DS      194.610
# 4      XOne      159.320
# 5      WiiU       82.190
# 6        PC       62.650
# 7       PSV       49.180
# 8       Wii       35.370
# 9        DS       12.550
# 10      PSP       11.190

# %%
(sns.barplot(x='platform', y='total_sales', palette='deep', 
    data=platforms_actual_sales.sort_values(by='total_sales')) 
    .set(ylim=(0,350),title='Количество проданных игр по платформам 2012-2016 гг.', 
    xlabel='Платформа', 
    ylabel='Количество продаж (в млн. штук)'))
   
plt.show()

# %% [markdown]
# В исследуемый период по продажам лидируют PS4, PS3, X360, в то же время разумно помимо них посмотреть на продажи таких платформ как 3DS, XOne, WiiU и PC. Построим таблицу, посмотрим на продажи этих платформ по каждому году исследуемого периода.

# %%
best_platforms_actual = list(platforms_actual_sales.loc[:6, 'platform'])
display(best_platforms_actual)
# Out:
# ['PS4', 'PS3', 'X360', '3DS', 'XOne', 'WiiU', 'PC']

# %%
top_platforms = (platforms_actual[platforms_actual.platform.isin(best_platforms_actual)]
                        .pivot_table(index=['platform', 'year_of_release'], 
                        values='total_sales', aggfunc='sum').reset_index())
display(top_platforms.head())
# Out:
#   platform  year_of_release  total_sales
# 0      3DS             2012       51.360
# 1      3DS             2013       56.570
# 2      3DS             2014       43.760
# 3      3DS             2015       27.780
# 4      3DS             2016       15.140

# %%
fig, axes = plt.subplots(1, 7, figsize=(17.6, 7), sharey=True)
fig.suptitle('Количество проданных игр на платформах по годам')

sns.barplot(ax=axes[0], x='year_of_release', y='total_sales', 
palette='deep', data=top_platforms.query('platform == "3DS"'))
axes[0].set(title='3DS', xlabel='Год выпуска', ylabel='Количество проданных копий (в млн. штук)')

sns.barplot(ax=axes[1], x='year_of_release', y='total_sales', 
palette='deep', data=top_platforms.query('platform == "PS3"'))
axes[1].set(title='PS3', xlabel='Год выпуска', ylabel='Количество проданных копий (в млн. штук)')

sns.barplot(ax=axes[2], x='year_of_release', y='total_sales', 
palette='deep', data=top_platforms.query('platform == "PS4"'))
axes[2].set(title='PS4', xlabel='Год выпуска', ylabel='Количество проданных копий (в млн. штук)')

sns.barplot(ax=axes[3], x='year_of_release', y='total_sales', 
palette='deep', data=top_platforms.query('platform == "X360"'))
axes[3].set(title='X360', xlabel='Год выпуска', ylabel='Количество проданных копий (в млн. штук)')

sns.barplot(ax=axes[4], x='year_of_release', y='total_sales', 
palette='deep', data=top_platforms.query('platform == "XOne"'))
axes[4].set(title='XOne', xlabel='Год выпуска', ylabel='Количество проданных копий (в млн. штук)')

sns.barplot(ax=axes[5], x='year_of_release', y='total_sales', 
palette='deep', data=top_platforms.query('platform == "WiiU"'))
axes[5].set(title='WiiU', xlabel='Год выпуска', ylabel='Количество проданных копий (в млн. штук)')

sns.barplot(ax=axes[6], x='year_of_release', y='total_sales', 
palette='deep', data=top_platforms.query('platform == "PC"'))
axes[6].set(title='PC', xlabel='Год выпуска', ylabel='Количество проданных копий (в млн. штук)')
# Out:
# [Text(0.5, 1.0, 'PC'),
#  Text(0.5, 0, 'Год выпуска'),
#  Text(0, 0.5, 'Количество проданных копий (в млн. штук)')]

# %% [markdown]
# Заметное падение продаж в исследуемый период отмечается у X360 и PS3, что вообщем-то ожидаемо, поскольку дата выхода указанных платформ приходится задолго до исследуемого периода (в 2006-2007 г.), а как мы выяснили ранее (и это подтверждается на графиках) по истечении 5-6 лет с даты выпуска платформы, продажи заметно снижаются. Кроме того, в указанный период вышло новое поколение платформы каждого из производителей (XOne и PS4), что не могло не сказаться на продажах игр для предыдущего поколения платформы.
#
# Рост продаж в исследуемый период наблюдается у PS4 и XOne, что неудивительно, поскольку обе приставки вышли на рынок как раз в этот период, а именно: для XOne год релиза в разных странах пришелся на конец 2013 г.- конец 2014 г., а для PS4 год релиза в разных странах пришелся на конец 2013 г. - начало 2014 г.
#
# Потенциально прибыльными платформами в 2017 году могут быть PS4, XOne, 3DS, WiiU, PC (как наиболее устойчивая платформа, поскольку срок ее существования ограничен только сроком существования персональных компьютеров) и PS3, поскольку у последнего хоть и имеется спад продаж, но не такой резкий как у X360, что дает основания считать, что продажи игр для данной платформы также будут оставаться на некотором уровне.

# %% [markdown]
# ### Распределение игр по количеству продаж для актуальных платформ

# %% [markdown]
# Отберем платформы, которые мы выделили для исследования в предыдущей главе и построим по ним график "ящик с усами".

# %%
top_platforms_actual = df.query('platform in ("PS4", "PS3", "3DS", "XOne", "WiiU", "PC") and year_of_release > 2011')
top_platforms_actual.head()
# Out:
#                           name platform  year_of_release         genre  \
# 16          Grand Theft Auto V      PS3             2013        Action
# 31   Call of Duty: Black Ops 3      PS4             2015       Shooter
# 33         Pokemon X/Pokemon Y      3DS             2013  Role-Playing
# 34  Call of Duty: Black Ops II      PS3             2012       Shooter
# 42          Grand Theft Auto V      PS4             2014        Action
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 16     7.020     9.090     0.980        3.960        97.000       8.200
# 31     6.030     5.860     0.360        2.380           NaN         NaN
# 33     5.280     4.190     4.350        0.780           NaN         NaN
# 34     4.990     5.730     0.650        2.420        83.000       5.300
# 42     3.960     6.310     0.380        1.970        97.000       8.300
#
#    rating  total_sales
# 16      M       21.050
# 31    NaN       14.630
# 33    NaN       14.600
# ...

# %%
box_top = (top_platforms_actual.groupby('platform')
        .agg({'total_sales' : ['sum', 'mean', 'median','min','max']}).reset_index())
box_top
# Out:
#   platform total_sales
#                    sum  mean median   min    max
# 0      3DS     194.610 0.491  0.110 0.010 14.600
# 1       PC      62.650 0.251  0.080 0.010  5.140
# 2      PS3     288.790 0.586  0.200 0.010 21.050
# 3      PS4     314.140 0.801  0.200 0.010 14.630
# 4     WiiU      82.190 0.559  0.220 0.010  7.090
# 5     XOne     159.320 0.645  0.220 0.010  7.390

# %%
fig, boxplot = plt.subplots(figsize = (16, 9))
boxplot = (sns.boxplot(y='platform', x='total_sales', data=top_platforms_actual)
    .set(xlim=(-0.2, 6), title='Распределение игр по количеству проданных копий для актуальных платформ',
    xlabel='Количество проданных копий (в млн. штук)',
    ylabel='Платформа'))

plt.show()

# %% [markdown]
# Практически для всех платформ характерно распределение продаж большей части игр в количестве менее 1 млн. копий (что для продаж со всего мира весьма немного).
#
# Среднее количество проданных экземпляров находится в диапазоне от 10 до 800 тысяч копий, однако медианные значения большинства продаж (за исключением PC и 3DS) составляют 200 тысяч копий. Это связано с тем, что в платформах, в которых средние значения заметно превышают медианное, имеется большое количество игр, продажи которых кратно превышают продажи остальных игр.
#
# Количество проданных копий игр для платформ PS4 и XOne примерно схоже, т.е. большая часть игр продается в промежутке от 0.1 до 0.8 млн копий, но на PS4 и на PS3 гораздо больше игр, продажи которых кратно превышают средние значения продаж игр (от 2 до 14.5 млн.), что также можно отметить и для платформы 3DS (от 0.8 до 14.5 млн.).

# %% [markdown]
# ### Зависимость между отзывами критиков/пользователей и продажами для актуальных платформ

# %% [markdown]
# Посмотрим на корреляцию корреляцию Пирсона между общим количеством продаж и оценками критиков/пользователей для PS4. Затем построим диаграмму рассеивания для отображения зависимости указанных показателей.

# %%
pc4_factors_sales = platforms_actual.query('platform == "PS4"')[['critic_score', 'user_score', 'total_sales']]

# %%
print(pc4_factors_sales['total_sales'].corr(pc4_factors_sales['critic_score']))
print(pc4_factors_sales['total_sales'].corr(pc4_factors_sales['user_score']))
# Out:
# 0.40656790206178145
# -0.03195711020455645

# %%
fig, ax = plt.subplots(1, 2)
sns.scatterplot(y='total_sales', x='critic_score', data=pc4_factors_sales, ax=ax[0]) \
    .set(title='Зависимость продаж от оценки критиков (PS4)', \
    xlabel='Оценка критиков', ylabel='Количество проданных копий (в млн. штук)')
sns.scatterplot(y='total_sales', x='user_score', data=pc4_factors_sales, ax=ax[1]) \
    .set(title='Зависимость продаж от оценки пользователей (PS4)', \
    xlabel='Оценка пользователей', ylabel='Количество проданных копий (в млн. штук)')

fig.show()

# %% [markdown]
# Для платформы PS4 характерно наличие положительной взаимосвязи между оценками критиков и продажами игр, но не слишком сильной (коэффициент корреляции Пирсона 0.40). При этом какой-либо взаимосвязи между оценками пользователей и продажами игр не прослеживается (коэффициент корреляции Пирсона -0.03).

# %% [markdown]
# Далее посмотрим имеется ли такая взаимосвязь по остальным платформам, для чего выделим их в отдельную таблицу.

# %%
factors_sales_platform = (platforms_actual.query('platform in ("PS3", "3DS", "XOne", "WiiU", "PC")')
                          [['platform','critic_score', 'user_score', 'total_sales']])

# %% [markdown]
# Построим диаграмму рассеивания для отображения зависимости указанных показателей, а затем посмотрим на корреляцию Пирсона между общим количеством продаж и оценками критиков.

# %%
lst = ["PS3", "3DS", "XOne", "WiiU", "PC"]

for value in lst:
    critical_score = factors_sales_platform.query('platform == @value')['critic_score']
    user_score = factors_sales_platform.query('platform == @value')['user_score']
    total_sales = factors_sales_platform.query('platform == @value')['total_sales']
    print(f'Коэффициент корреляции Пирсона для оценок критиков и продажами для {value}:', total_sales.corr(critical_score))
# Out:
# Коэффициент корреляции Пирсона для оценок критиков и продажами для PS3: 0.33149725926295903
# Коэффициент корреляции Пирсона для оценок критиков и продажами для 3DS: 0.3208028695360786
# Коэффициент корреляции Пирсона для оценок критиков и продажами для XOne: 0.4169983280084016
# Коэффициент корреляции Пирсона для оценок критиков и продажами для WiiU: 0.34837976012017496
# Коэффициент корреляции Пирсона для оценок критиков и продажами для PC: 0.23724324311567896

# %%
(sns.relplot(y='total_sales', x='critic_score', col='platform', col_wrap=2,
            data=factors_sales_platform)
    .set(xlabel='Оценка критиков', ylabel='Количество проданных копий (в млн. штук)'))

# %% [markdown]
# Практически на всех платформах зависимость между оценками критиков и продажами прослеживается, но довольно слабая, что в целом соотносится с данными по PS4.

# %% [markdown]
# Проделаем тоже самое для выявления зависимости между общим количеством продаж и оценками пользователей.

# %%
(sns.relplot(y='total_sales', x='user_score', col='platform', col_wrap=2,
            data=factors_sales_platform)
    .set(xlabel='Оценка пользователей', ylabel='Количество проданных копий (в млн. штук)'))

# %%
for value in lst:
    critical_score = factors_sales_platform.query('platform == @value')['critic_score']
    user_score = factors_sales_platform.query('platform == @value')['user_score']
    total_sales = factors_sales_platform.query('platform == @value')['total_sales']
    print(f'Коэффициент корреляции Пирсона для оценок пользователей и продаж для {value}:', total_sales.corr(user_score))
# Out:
# Коэффициент корреляции Пирсона для оценок пользователей и продаж для PS3: -0.005143522887113798
# Коэффициент корреляции Пирсона для оценок пользователей и продаж для 3DS: 0.19758263411038599
# Коэффициент корреляции Пирсона для оценок пользователей и продаж для XOne: -0.0689250532827942
# Коэффициент корреляции Пирсона для оценок пользователей и продаж для WiiU: 0.40021902021486194
# Коэффициент корреляции Пирсона для оценок пользователей и продаж для PC: -0.12186747630735574

# %% [markdown]
# Практически на всех платформах зависимость между оценками пользователей и продажами вообще не прослеживается, что также соотносится с данными по PS4.
#
# Платформа WiiU выделяется тем, что для нее имеется некоторая взаимосвязь как между оценками критиков и продажами, так и между оценками пользователей и продажами, но не сильная (коэффициент корреляции Пирсона 0.35 и 0.4 соответственно).

# %% [markdown]
# ### Распределение игр по жанрам

# %% [markdown]
# Посмотрим какие жанры игр являются самыми прибыльными, для чего выделим их в отдельную таблицу и проанализируем, построив диаграмму.

# %%
top_platforms_actual.head()
# Out:
#                           name platform  year_of_release         genre  \
# 16          Grand Theft Auto V      PS3             2013        Action
# 31   Call of Duty: Black Ops 3      PS4             2015       Shooter
# 33         Pokemon X/Pokemon Y      3DS             2013  Role-Playing
# 34  Call of Duty: Black Ops II      PS3             2012       Shooter
# 42          Grand Theft Auto V      PS4             2014        Action
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 16     7.020     9.090     0.980        3.960        97.000       8.200
# 31     6.030     5.860     0.360        2.380           NaN         NaN
# 33     5.280     4.190     4.350        0.780           NaN         NaN
# 34     4.990     5.730     0.650        2.420        83.000       5.300
# 42     3.960     6.310     0.380        1.970        97.000       8.300
#
#    rating  total_sales
# 16      M       21.050
# 31    NaN       14.630
# 33    NaN       14.600
# ...

# %%
genres = (top_platforms_actual.pivot_table(index='genre', values='total_sales', aggfunc=['sum', 'mean','median'])
        .reset_index())
genres.columns = ['genre', 'total_sales', 'mean_sales', 'median_sales']
genres.head()
# Out:
#        genre  total_sales  mean_sales  median_sales
# 0     Action      326.860       0.477         0.140
# 1  Adventure       20.450       0.149         0.060
# 2   Fighting       36.950       0.493         0.160
# 3       Misc       47.140       0.365         0.130
# 4   Platform       53.660       0.801         0.250

# %%
(sns.barplot(x='genre', y='total_sales', palette='deep', 
    data=genres.sort_values(by='total_sales', ascending=False)) 
    .set(ylim=(0,350),title='Общее количество проданных игр по жанрам 2012-2016 гг.', 
    xlabel='Название жанра', 
    ylabel='Количество проданных копий (в млн. штук)'))
   
plt.show()

# %% [markdown]
# Посмотрим на средние и медианные значения показателей продаж игр по жанрам.

# %%
(sns.barplot(x='genre', y='mean_sales', palette='deep', 
    data=genres.sort_values(by='mean_sales', ascending=False)) 
    .set(ylim=(0,2),title='Среднее количество проданных игр по жанрам 2012-2016 гг.', 
    xlabel='Название жанра', 
    ylabel='Количество проданных копий (в млн. штук)'))
   
plt.show()

# %%
(sns.barplot(x='genre', y='median_sales', palette='deep', 
    data=genres.sort_values(by='median_sales', ascending=False)) 
    .set(ylim=(0,1),title='Медианные значения количества проданных игр по жанрам 2012-2016 гг.', 
    xlabel='Название жанра', 
    ylabel='Количество проданных копий (в млн. штук)'))
   
plt.show()

# %% [markdown]
# Самые продаваемые игры жанров `Shooter`, `Sports` и `Platform`, что в целом предсказуемо. По сравнению с играми других жанров, эти игры:
# - относительно простые и интуитивно понятные;
# - довольно динамичные;
# - позволяют игроку активно использовать персонажа, которым играешь;
# - довольно часто предусмотрена возможность совместной игры (в т.ч. по сети Интернет).
# - в этих жанрах имеются игры, которые выходят на протяжении длительного периода времени и составляют серию игр, вследствие чего серия позволяет наращивать поклонников игры довольно продолжительный период времени.
#
# Самые низкие продажи игр жанров `Strategy`, `Adventure`, `Puzzle` в целом также ожидаемы. Многие пользователи ищут в играх расслабления после трудового дня/учебы, т.е. игра как правило является способом отвлечься и отдохнуть. В то же время эти два жанра предусматривают необходимость глубокого погружения в суть игры, наличия некоторых тактических навыков или навыков разгадывания головоломок, что нравится не такому большому количеству людей, как в других жанрах.

# %% [markdown]
# ## Портрет пользователя каждого региона (NA, EU, JP)

# %% [markdown]
# ### Наиболее популярные игровые платформы (топ-5)  в каждом из регионов

# %% [markdown]
# Выделим продажи игр по платформам в каждом из регионов в отдельную таблицу, построим диаграмму.

# %%
platform_by_regions = (top_platforms_actual.pivot_table(index='platform', values=['na_sales', 'eu_sales', 'jp_sales'], 
                    aggfunc='sum').reset_index())
platform_by_regions
# Out:
#   platform  eu_sales  jp_sales  na_sales
# 0      3DS    42.640    87.790    55.310
# 1       PC    37.760     0.000    19.120
# 2      PS3   106.860    35.290   103.380
# 3      PS4   141.090    15.960   108.740
# 4     WiiU    25.130    13.010    38.100
# 5     XOne    51.590     0.340    93.120

# %%
fig, axes = plt.subplots(1, 3, figsize=(14, 8), sharey=True)
fig.suptitle('Наиболее популярные платформы в регионах продаж', fontweight='bold', size=20)

sns.barplot(ax=axes[0], x='platform', y='eu_sales', 
palette='deep', data=platform_by_regions.nlargest(5,'eu_sales'))
axes[0].set(title='Европа', xlabel='Платформа', ylabel='Количество проданных копий (в млн. штук)')

sns.barplot(ax=axes[1], x='platform', y='na_sales', 
palette='deep', data=platform_by_regions.nlargest(5,'na_sales'))
axes[1].set(title='Северная Америка', xlabel='Платформа', ylabel='Количество проданных копий (в млн. штук)')

sns.barplot(ax=axes[2], x='platform', y='jp_sales', 
palette='deep', data=platform_by_regions.nlargest(5,'jp_sales'))
axes[2].set(title='Япония', xlabel='Платформа', ylabel='Количество проданных копий (в млн. штук)')
# Out:
# [Text(0.5, 1.0, 'Япония'),
#  Text(0.5, 0, 'Платформа'),
#  Text(0, 0.5, 'Количество проданных копий (в млн. штук)')]

# %% [markdown]
# Для Европы самыми популярными являются PS4, PS3, при этом для других платформ, входящих в топ-5 (XOne, 3DS и PC) продажи игр гораздо ниже. В то же время продажи игр для платформ XOne, 3DS и PC находятся примерно на одном уровне.
#
# Для Северной Америки самой популярной платформой помимо PS3, PS4 также является XOne, что в целом предсказуемо, поскольку производитель этой платформы - Microsoft находится в США. Продажи игр на 3DS и WiiU гораздо ниже и находятся примерно на одном уровне.
#
# Для Японии характерны высокие продажи игр для платформы 3DS, а для платформы, которая по продажам находится на втором месте (PS3) продажи практически в два раза ниже, а PS4 и WiiU имеют еще более низкие результаты продаж. Отличие Японии от других регионов в том, что высокие продажи игр здесь только для тех платформ, производителями которых является эта страна (т.е. практически отсутствуют продажи для XOne).

# %% [markdown]
# ### Наиболее популярные жанры игр (топ-5) в каждом из регионов

# %% [markdown]
# Выделим продажи игр по жанрам в каждом из регионов в отдельную таблицу, построим диаграмму.

# %%
genres_by_regions = (top_platforms_actual.pivot_table(index='genre', values=['na_sales', 'eu_sales', 'jp_sales'], aggfunc='sum')
        .reset_index())
genres_by_regions.head()
# Out:
#        genre  eu_sales  jp_sales  na_sales
# 0     Action   122.480    41.500   121.910
# 1  Adventure     7.650     4.240     6.360
# 2   Fighting     9.160     8.260    15.750
# 3       Misc    14.690     9.020    18.980
# 4   Platform    18.330     8.570    22.090

# %%
fig, axes = plt.subplots(1, 3, figsize=(14, 8), sharey=True)
fig.suptitle('Наиболее популярные жанры игр в регионах продаж', fontweight="bold", size=20)

sns.barplot(ax=axes[0], x='genre', y='eu_sales', 
palette='deep', data=genres_by_regions.nlargest(5,'eu_sales'))
axes[0].set(title='Европа', xlabel='Жанр', ylabel='Количество проданных копий (в млн. штук)')

sns.barplot(ax=axes[1], x='genre', y='na_sales', 
palette='deep', data=genres_by_regions.nlargest(5,'na_sales'))
axes[1].set(title='Северная Америка', xlabel='Жанр', ylabel='Количество проданных копий (в млн. штук)')

sns.barplot(ax=axes[2], x='genre', y='jp_sales', 
palette='deep', data=genres_by_regions.nlargest(5,'jp_sales'))
axes[2].set(title='Япония', xlabel='Жанр', ylabel='Количество проданных копий (в млн. штук)')
# Out:
# [Text(0.5, 1.0, 'Япония'),
#  Text(0.5, 0, 'Жанр'),
#  Text(0, 0.5, 'Количество проданных копий (в млн. штук)')]

# %% [markdown]
# Для Европы и Северной Америки самыми продаваемыми являются игры жанров `Action` и `Shooter`, что не отличается от предпочтений в жанрах по общей выборке. Схожими для данных регионов также являются предпочтения пользователей к играм жанров `Sport` и `Role-Playing`. Различия в предпочитаемых жанрах в следующем: в Европе в топ-5 игр входит жанр `Racing`, а в Северной Америке - `Platform`.
#
# Для Японии самыми продаваемыми являются игры жанров `Role-Playing`, `Shooter` и`Action`, что в целом схоже с жанрами, входящими в топ-5 в Северной Америке и Европе. Но оставшиеся жанры `Misc` и `Simulation` являются наиболее популярными только в этом регионе.

# %% [markdown]
# ### Влияние рейтинга ESRB на продажи в регионах

# %% [markdown]
# Выясним какие рейтингами ESRB имеются для игр в исследуемом периоде.

# %%
top_platforms_actual.rating.unique()
# Out:
# array(['M', nan, 'E', 'T', 'E10+'], dtype=object)

# %% [markdown]
# Рейтинг игр ESRB основан на их содержании аналогично рейтинговым системам кинофильмов. Рейтинг игры напечатан на упаковке, содержится в её рекламе и указан на сайте игры. В рассматриваемой выборке имеются следующие рейтинги:
# - «E» («Everyone») — «Для всех»;
# - «E10+» («Everyone 10 and older»): «Игра подходит для лиц от 10 лет и старше»;
# - «T» («Teen») — «Подросткам»: «Игра подходит для лиц от 13 лет и старше»;
# - «M» («Mature») — «Для взрослых».
#
# Посмотрим влияет ли рейтинг ESRB на продажи в каждом из исследуемых регионов.

# %%
top_platforms_actual.head()
# Out:
#                           name platform  year_of_release         genre  \
# 16          Grand Theft Auto V      PS3             2013        Action
# 31   Call of Duty: Black Ops 3      PS4             2015       Shooter
# 33         Pokemon X/Pokemon Y      3DS             2013  Role-Playing
# 34  Call of Duty: Black Ops II      PS3             2012       Shooter
# 42          Grand Theft Auto V      PS4             2014        Action
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 16     7.020     9.090     0.980        3.960        97.000       8.200
# 31     6.030     5.860     0.360        2.380           NaN         NaN
# 33     5.280     4.190     4.350        0.780           NaN         NaN
# 34     4.990     5.730     0.650        2.420        83.000       5.300
# 42     3.960     6.310     0.380        1.970        97.000       8.300
#
#    rating  total_sales
# 16      M       21.050
# 31    NaN       14.630
# 33    NaN       14.600
# ...

# %%
rating_by_regions = (top_platforms_actual.pivot_table(index='rating', 
                    values=['na_sales', 'eu_sales', 'jp_sales'], 
                    aggfunc='sum').reset_index())
rating_by_regions.head()
# Out:
#   rating  eu_sales  jp_sales  na_sales
# 0      E    92.230    26.590    84.920
# 1   E10+    36.590     7.560    46.820
# 2      M   153.700    18.170   153.440
# 3      T    43.790    19.700    49.350

# %%
fig, axes = plt.subplots(1, 3, figsize=(14, 8), sharey=True)
fig.suptitle('Распределение продаж игр в регионах по рейтингу ESRB', fontweight="bold", size=20)

sns.barplot(ax=axes[0], x='rating', y='eu_sales',
palette='deep', data=rating_by_regions.nlargest(5,'eu_sales'))
axes[0].set(title='Европа', xlabel='Возрастной рейтинг', ylabel='Количество проданных копий (в млн. штук)')

sns.barplot(ax=axes[1], x='rating', y='na_sales', 
palette='deep', data=rating_by_regions.nlargest(5,'na_sales'))
axes[1].set(title='Северная Америка', xlabel='Возрастной рейтинг', ylabel='Количество проданных копий (в млн. штук)')

sns.barplot(ax=axes[2], x='rating', y='jp_sales',
palette='deep', data=rating_by_regions.nlargest(5,'jp_sales'))
axes[2].set(title='Япония', xlabel='Возрастной рейтинг', ylabel='Количество проданных копий (в млн. штук)')
# Out:
# [Text(0.5, 1.0, 'Япония'),
#  Text(0.5, 0, 'Возрастной рейтинг'),
#  Text(0, 0.5, 'Количество проданных копий (в млн. штук)')]

# %% [markdown]
# Для Европы и Северной Америки характерно примерно одинаковое количество продаж игр категорий "для взрослых" и "для всех", причем категория игр "для взрослых" лидирует в обоих регионах с заметным перевесом.
#
# Для Японии же наибольшие продажи игр в категории "для всех", а продажи игр категорий "для подростков" и "для взрослых" находятся примерно на одинаковом уровне.

# %% [markdown]
# ## Проверка гипотез и пояснения

# %% [markdown]
# ### Проверка гипотезы о равенстве пользовательских рейтингов платформ Xbox One и PC

# %% [markdown]
# Для проверки гипотезы необходимо в столбце с оценками пользователей посмотреть на распределение, а также на наличие аномальных значений.

# %%
supposition_1 = top_platforms_actual.query('platform in("PC", "XOne")')
supposition_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 497 entries, 99 to 16421
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             497 non-null    object
#  1   platform         497 non-null    object
#  2   year_of_release  497 non-null    int32
#  3   genre            497 non-null    object
#  4   na_sales         497 non-null    float64
#  5   eu_sales         497 non-null    float64
#  6   jp_sales         497 non-null    float64
#  7   other_sales      497 non-null    float64
#  8   critic_score     367 non-null    float64
#  9   user_score       388 non-null    float64
#  10  rating           371 non-null    object
#  11  total_sales      497 non-null    float64
# dtypes: float64(7), int32(1), object(4)
# memory usage: 48.5+ KB

# %%
supposition_1.user_score.describe()
# Out:
# count   388.000
# mean      6.472
# std       1.537
# min       1.400
# 25%       5.700
# 50%       6.800
# 75%       7.600
# max       9.300
# Name: user_score, dtype: float64

# %% [markdown]
# Часть значений в столбце с пользовательскими рейтингами, необходимыми для проверки гиппотезы, являются пропущенными, необходимо удалить их. В то же время каких-либо аномальных значений в данном столбце не имеется.

# %%
supposition_1 = supposition_1.dropna(subset=['user_score'], axis=0).reset_index(drop=True)
print(supposition_1.user_score.isna().sum())
# Out:
# 0

# %% [markdown]
# **Введем основную и альтернативные гипотезы:**
#
# H0: Средние пользовательские рейтинги (оценки) для платформ `Xbox One`и `PC` не различаются.
# H1: Средние пользовательские рейтинги (оценки) для платформ `Xbox One`и `PC` различаются.

# %% [markdown]
# Выделим исследуемые признаки в отдельные таблицы.

# %%
xbox = supposition_1.query('platform == "XOne"')
pc = supposition_1.query('platform == "PC"')

# %%
display(xbox.head(1))
display(pc.head(1))
# Out:
#                  name platform  year_of_release   genre  na_sales  eu_sales  \
# 0  Grand Theft Auto V     XOne             2014  Action     2.810     2.190
#
#    jp_sales  other_sales  critic_score  user_score rating  total_sales
# 0     0.000        0.470        97.000       7.900      M        5.470
#          name platform  year_of_release         genre  na_sales  eu_sales  \
# 2  Diablo III       PC             2012  Role-Playing     2.440     2.160
#
#    jp_sales  other_sales  critic_score  user_score rating  total_sales
# 2     0.000        0.540        88.000       4.000      M        5.140

# %% [markdown]
# Проверим получившиеся таблицы с данными на нормальность распределения при помощи гистограмм и QQ-графиков.

# %%
# строим гистограмму
fig, ax = plt.subplots(1, 2)

sns.histplot(x='user_score', data=xbox, kde=True, ax=ax[0])
sns.histplot(x='user_score', data=pc, kde=True, ax=ax[1])
# Out:
# <AxesSubplot:xlabel='user_score', ylabel='Count'>

# %%
# строим qq-plot для нормального распределения
plt.subplot(2,2,1)
st.probplot(xbox['user_score'], dist="norm", plot=plt)
plt.subplot(2,2,2)
st.probplot(pc['user_score'], dist="norm", plot=plt)
plt.show()

# %% [markdown]
# Распределение значений в обеих выборках с некоторым допущением можно отнести к нормальному, предоставленные выборки независимы,. Для проверки равенства их средних полагаю возможным использовать t-тест. В то же время, поскольку сами выборки довольно небольшого размера, можно дополнительно вычислить и посмтреть средние значения по каждой выборке.

# %% [markdown]
# Посчитаем p-value, используя ttest из библиотеки scipy для сравнения средних двух выборок.
#
# Зададим уровень значимости: 𝛼 = 0.05
#
# Если p-value будет меньше выбранного уровня значимости 𝛼 = 0.05, то нулевую гипотезу об отсутствии отличий средних отвергнем. Иначе сделаем вывод, что данные не позволили нам отвергнуть нулевую гипотезу.

# %%
# зададим критический уровень статистической значимости
alpha_1 = .05

results_1 = st.ttest_ind(xbox.user_score, pc.user_score, equal_var=False)

print('p-значение: ', results_1.pvalue)

if (results_1.pvalue < alpha_1):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
    
print('Средние оценки пользователей для платформы "Xbox One":', xbox.user_score.mean())
print('Средние оценки пользователей для платформы "PC":', pc.user_score.mean())
# Out:
# p-значение:  0.5489537965134912
# Не получилось отвергнуть нулевую гипотезу
# Средние оценки пользователей для платформы "Xbox One": 6.52142857142857
# Средние оценки пользователей для платформы "PC": 6.428640776699027

# %% [markdown]
# Таким образом, на имеющихся данных, на уровне значимости 5% нет оснований отвергнуть нулевую гипотезу, согласно которой cредние пользовательские оценки для платформ `Xbox One`и `PC` не различаются.

# %% [markdown]
# ### Проверка гипотезы о равенстве пользовательских рейтингов жанров Action и Sports

# %% [markdown]
# Для проверки гипотезы необходимо в столбце с оценками пользователей посмотреть на распределение и наличие аномальных значений.

# %%
supposition_2 = top_platforms_actual.query('genre in("Action", "Sports")')
supposition_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 869 entries, 16 to 16439
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             869 non-null    object
#  1   platform         869 non-null    object
#  2   year_of_release  869 non-null    int32
#  3   genre            869 non-null    object
#  4   na_sales         869 non-null    float64
#  5   eu_sales         869 non-null    float64
#  6   jp_sales         869 non-null    float64
#  7   other_sales      869 non-null    float64
#  8   critic_score     457 non-null    float64
#  9   user_score       533 non-null    float64
#  10  rating           551 non-null    object
#  11  total_sales      869 non-null    float64
# dtypes: float64(7), int32(1), object(4)
# memory usage: 84.9+ KB

# %%
supposition_2.user_score.describe()
# Out:
# count   533.000
# mean      6.479
# std       1.568
# min       0.200
# 25%       5.700
# 50%       6.800
# 75%       7.700
# max       9.100
# Name: user_score, dtype: float64

# %% [markdown]
# Часть значений в столбце с пользовательскими рейтингами, необходимыми для проверки гиппотезы, являются пропущенными, необходимо их удалить. В то же время каких-либо аномальных значений в данном столбце не имеется.

# %%
supposition_2 = supposition_2.dropna(subset=['user_score'], axis=0).reset_index(drop=True)
print(supposition_2.user_score.isna().sum())
# Out:
# 0

# %% [markdown]
# **Введем основную и альтернативные гипотезы:**
#
# H0: Средние пользовательские рейтинги (оценки) для игр жанров `Action`и `Sports` не различаются.
# H1: Средние пользовательские рейтинги (оценки) для игр жанров `Action`и `Sports` различаются.

# %% [markdown]
# Выделим исследуемые признаки в отдельные таблицы.

# %%
action = supposition_2.query('genre == "Action"')
sports = supposition_2.query('genre == "Sports"')

# %%
display(action.head(1))
display(sports.head(1))
# Out:
#                  name platform  year_of_release   genre  na_sales  eu_sales  \
# 0  Grand Theft Auto V      PS3             2013  Action     7.020     9.090
#
#    jp_sales  other_sales  critic_score  user_score rating  total_sales
# 0     0.980        3.960        97.000       8.200      M       21.050
#       name platform  year_of_release   genre  na_sales  eu_sales  jp_sales  \
# 2  FIFA 16      PS4             2015  Sports     1.120     6.120     0.060
#
#    other_sales  critic_score  user_score rating  total_sales
# 2        1.280        82.000       4.300      E        8.580

# %% [markdown]
# Проверим получившиеся таблицы с данными на нормальность распределения при помощи гистограмм и QQ-графиков.

# %%
# строим гистограмму
fig, ax = plt.subplots(1, 2)

sns.histplot(x='user_score', data=action, kde=True, ax=ax[0])
sns.histplot(x='user_score', data=sports, kde=True, ax=ax[1])
# Out:
# <AxesSubplot:xlabel='user_score', ylabel='Count'>

# %%
# строим qq-plot для нормального распределения
plt.subplot(2,2,1)
st.probplot(action['user_score'], dist="norm", plot=plt)
plt.subplot(2,2,2)
st.probplot(sports['user_score'], dist="norm", plot=plt)
plt.show()

# %% [markdown]
# Распределение значений в обеих выборках можно отнести к нормальному, предоставленные выборки независимы. Для проверки равенства их средних полагаю возможным использовать t-тест. В то же время, поскольку сами выборки довольно небольшого размера, можно дополнительно вычислить и сравнить имеется ли существенное различие между средними значениями по каждой выборке.

# %% [markdown]
# Посчитаем p-value, используя ttest из библиотеки scipy для сравнения средних двух выборок.
#
# Уровень значимости: 𝛼 = 0.05
#
# Если p-value будет меньше выбранного уровня значимости 𝛼 = 0.05, то нулевую гипотезу об отсутствии отличий средних отвергнем. Иначе сделаем вывод, что данные не позволили нам отвергнуть нулевую гипотезу.

# %%
# зададим критический уровень статистической значимости
alpha_2 = .05

results_2 = st.ttest_ind(action.user_score, sports.user_score, equal_var=False)
print('p-значение: ', results_2.pvalue)

if (results_2.pvalue < alpha_2):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
    
print('Средние оценки пользователей жанра игр "Action":', action.user_score.mean())
print('Средние оценки пользователей жанра игр "Sports":', sports.user_score.mean())
# Out:
# p-значение:  1.6664626580053579e-15
# Отвергаем нулевую гипотезу
# Средние оценки пользователей жанра игр "Action": 6.8445876288659875
# Средние оценки пользователей жанра игр "Sports": 5.501379310344829

# %% [markdown]
# Таким образом, на имеющихся данных, на уровне значимости 5% имеются основания отвергнуть нулевую гипотезу, согласно которой средние пользовательские рейтинги (оценки) для игр жанров `Action`и `Sports` не различаются.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В ходе исследования была проанализирована выборка об играх, проданных в период с 2012 по 2016 год. Исследование было направлено на определение прогноза продаж игр (и платформ на которых они будут продаваться) на 2017 год.
#
# При прогнозе продаж игр на 2017 год необходимо принять во внимание и учесть:
# - регион, в котором осуществляются продажи;
# - является ли магазин стационарным или онлайн магазином;
# - осуществляются ли продажи игр только на физических носителях, только в виде цифровых копий, или в смешанном виде (как на физических носителях, так и в виде цифровых копий).
# - при продаже цифровых копий узнать, рассчитаны ли они на продажу только в определенном регионе (с учетом имеющихся ограничений по продажам определенных игр в той или иной стране) или без таких ограничений (с возможностью выбора языка и т.п.).
#
# Если принять во внимание, что магазин осуществляет продажи во все регионы как на физических носителях, так и на цифровых, то необходимо предварительно выяснить соотношение продаж пользователям, относящимся к соответствующему региону и принимать решение о планировании продаж с учетом указанных данных. При этом при планировании продаж на 2017 год необходимо также учесть, что:
# - для Европы самыми популярными являются платформы PS4, PS3, XOne, 3DS и PC, но продажи игр на последних трех гораздо ниже. Пользователям данного региона больше всего нравятся игры жанров Action и Shooter, Sport, Role-Playing и Racing с рейтингом ESRB «E» («Для всех») и «M» («Для взрослых»);
# - для Северной Америки самыми популярными являются платформы PS4, PS3, XOne, 3DS и WiiU, но продажи игр на последних двух гораздо ниже. Пользователям данного региона больше всего нравятся игры жанров Action и Shooter, Sport, Role-Playing и Platform с рейтингом ESRB «E» («Для всех») и «M» («Для взрослых»);
# - для Японии самыми популярными являются платформы 3DS, PS3, PS4 и WiiU, при этом продажи первой гораздо выше остальных. Пользователям данного региона больше всего нравятся игры жанров Role-Playing, Shooter, Action, Sport, Misc и Simulation с рейтингом ESRB «E» («Для всех»), «M» («Для взрослых») и «T» («Для подростков»).
